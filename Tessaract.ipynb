# %% [markdown]
# <a href="https://colab.research.google.com/github/Abhishek92kumar/AI/blob/main/Tessaract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://bhadreshpsavani.medium.com/how-to-use-tesseract-library-for-ocr-in-google-colab-notebook-5da5470e4fe0

# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 35 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 0s (26.5 MB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
# !pip install pytesseract

# %%
import pytesseract
import cv2
img = cv2.imread('try.png')
# img = cv2.resize(img, (720, 480))
from google.colab.patches import cv2_imshow
cv2_imshow(img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=630x630>
# -1

# %%
import pytesseract
import cv2
img = cv2.imread('try.png')
img = cv2.resize(img, (600, 360))
# print(pytesseract.image_to_string(img))
cv2_imshow(img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=600x360>
# -1

# %%
import pytesseract
pytesseract.image_to_data(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pytesseract/pytesseract.py in get_tesseract_version()
#     387     try:
# --> 388         output = subprocess.check_output(
#     389             [tesseract_cmd, '--version'],
#
# /usr/lib/python3.10/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     420
# --> 421     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     422                **kwargs).stdout
#
# /usr/lib/python3.10/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     502
# --> 503     with Popen(*popenargs, **kwargs) as process:
#     504         try:
#
# ...

# %% [markdown]
# Step2. import libraries

# %%
import pytesseract
import shutil
import os
import random
try:
 from PIL import Image
except ImportError:
 import Image

# %% [markdown]
# Step3. Upload Image to the Colab

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6d499657-4326-40ce-8b80-ae7576464f32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d499657-4326-40ce-8b80-ae7576464f32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Step4. Text Extraction

# %%
image_path_in_colab='try.png'
extractedInformation = pytesseract.image_to_string(Image.open(image_path_in_colab))
print(extractedInformation)
# Out:
# FAILURE
# Is
# NOT
# AN
# OPTION

# %% [markdown]
# Step5. Detect Langauge other than English:

# %%
# French text image to string
extractedInformation = pytesseract.image_to_string(Image.open('test-european.jpg'), lang='fra')
print(extractedInformation)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-19-57cb0f9717fa> in <cell line: 2>()
#       1 # French text image to string
# ----> 2 extractedInformation = pytesseract.image_to_string(Image.open('test-european.jpg'), lang='fra')
#       3 print(extractedInformation)
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3225
#    3226     if filename:
# -> 3227         fp = builtins.open(filename, "rb")
#    3228         exclusive_fp = True
#    3229
#
# FileNotFoundError: [Errno 2] No such file or directory: 'test-european.jpg'

# %% [markdown]
# Step6. Get Bounding Boxes for Text

# %%
# Get bounding box estimates
print(pytesseract.image_to_boxes(Image.open(image_path_in_colab)))
# Out:
# F 197 430 225 467 0
# A 227 430 266 467 0
# I 270 430 284 467 0
# L 290 430 318 467 0
# U 322 429 358 467 0
# R 335 429 395 468 0
# E 364 430 433 468 0
# I 291 385 305 422 0
# s 308 384 340 423 0
# N 254 340 293 377 0
# O 298 340 339 378 0
# T 342 340 376 377 0
# A 272 295 312 333 0
# N 315 295 354 333 0
# O 202 250 243 289 0
# P 248 251 281 288 0
# T 284 251 318 288 0
# I 322 251 336 288 0
# O 341 250 382 289 0
# N 387 251 425 288 0
